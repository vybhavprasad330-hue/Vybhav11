# %%
def greet(name):
  print("Happy new year", name)

# %%
greet("Namith, Madhu, Manju, Manoj, Lohith, Azhar, Nandeesha")
# Out:
# Happy new year Namith, Madhu, Manju, Manoj, Lohith, Azhar, Nandeesha

# %%
greet("Maithreyi S, Likhitha, Lathashree, Kusuma, Nanditha, Indhushree, Maithri")
# Out:
# Happy new year Maithreyi S, Likhitha, Lathashree, Kusuma, Nanditha, Indhushree, Maithri

# %%
# list length
#to determine how many itemes a list has
a_list =["Apple", "Bannana", "Cherry"]
print(len(a_list))
# Out:
# 3

# %%
# list length
#to determine how many itemes a list has
a_list =[2,5,6,,3,6,3,6,3]
print(len(a_list)
# Out:
#   File "/tmp/ipython-input-35805769.py", line 3
#     a_list =[2,5,6,,3,6,3,6,3]
#                    ^
# SyntaxError: invalid syntax

# %%
list1 = ["apple","Banana","Cherry"]
list2 = [1,5,7,9,3]
list3 = [True, False, False]
print(len(list1) or list1)
print(list2)
print(list3)
# Out:
# 3
# [1, 5, 7, 9, 3]
# [True, False, False]

# %%
list1 = ["apple","Banana","Cherry"]
list2 = [1,5,7,9,3]
list3 = [True, False, False]
print(len(list1))
print(len(list2))
print(len(list3))
# Out:
# 3
# 5
# 3

# %%
for item in range(len(list1)):
  print(item)
# Out:
# 0
# 1
# 2

# %%
for item in range(len(list1)):
  print(list1[item])
# Out:
# apple
# Banana
# Cherry

# %%
print(type(list1))
print(type(list2))
print(type(list3))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'list'>

# %%
thislist2 = list(("apple","Banana","Cherry"))
print(thislist2)
# Out:
# ['apple', 'Banana', 'Cherry']

# %%
thislist2 = list(("apple","Banana","Cherry"))
print(thislist2[1])
# Out:
# Banana

# %%
thislist2 = list(("apple","Banana","Cherry"))
print(thislist2[2])
# Out:
# Cherry

# %%
print(thislist2[2//1])
# Out:
# Cherry

# %%
thislist2 = list(("apple","Banana","Cherry"))
print(thislist2[2-1])
print(thislist2[2**1])
# Out:
# Banana
# Cherry

# %%
thislist3 = ["apple","banana","cherry","date","eagle","fish","goat"]
print(thislist3)
print(thislist3[2:3])
print(thislist3[2:5])
print(thislist3[5:2])
print(thislist3[2:])
print(thislist3[-1:])
print(thislist3[:3])
print(thislist3[:-4])
print(thislist3[:])
print(thislist3[-4:-1])
print(thislist3[1:4])
print(thislist3[-5:5])
# Out:
# ['apple', 'banana', 'cherry', 'date', 'eagle', 'fish', 'goat']
# ['cherry']
# ['cherry', 'date', 'eagle']
# []
# ['cherry', 'date', 'eagle', 'fish', 'goat']
# ['goat']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry', 'date', 'eagle', 'fish', 'goat']
# ['date', 'eagle', 'fish']
# ['banana', 'cherry', 'date']
# ['cherry', 'date', 'eagle']

# %%
thislist3 = ["apple","banana","cherry","date","eagle","fish","goat"]
if "apple" in thislist3:
  print("yes, 'apple' is in the food list")
# Out:
# yes, 'apple' is in the food list

# %%
thislist = ["apple","banana","cherry","date","eagle","fish","goat"]
if "orange" not in thislist3:
  print("yes, 'orange' is not in the food list")
# Out:
# yes, 'orange' is not in the food list

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackberry"
print(thislist)
# Out:
# ['apple', 'blackberry', 'cherry']

# %%
thislist = ["apple","banana","cherry","date","eagle","fish","goat"]
thislist[1:3] = ["watermelon", "wine"]
print(thislist)
thislist[1:1] = ["watermelon", "rum"]
print(thislist)
# Out:
# ['apple', 'watermelon', 'wine', 'date', 'eagle', 'fish', 'goat']
# ['apple', 'watermelon', 'rum', 'watermelon', 'wine', 'date', 'eagle', 'fish', 'goat']

# %%
thislist = ["apple","banana","cherry","date","eagle","fish","goat"]
thislist[1:3] = ["watermelon", "wine"]
print(thislist)
thislist[1:1] = ["watermelon", "rum"]
print(thislist)
# Out:
# ['apple', 'watermelon', 'wine', 'date', 'eagle', 'fish', 'goat']
# ['apple', 'watermelon', 'rum', 'watermelon', 'wine', 'date', 'eagle', 'fish', 'goat']

# %%
thislist = ["apple","banana","cherry"]
thislist [1:3] = ["watermelon"]
print(thislist)
# Out:
# ['apple', 'watermelon']

# %%
thislist3 = ["apple","banana","cherry"]
thislist3.insert(2,"watermelon")
print(thislist3)
thislist3.insert(,"watermelon")
print(thislist3)
# Out:
# ['apple', 'banana', 'watermelon', 'cherry']
# ['watermelon', 'apple', 'banana', 'watermelon', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(1, "orange")
print(thislist)
# Out:
# ['apple', 'orange', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
tropical.extend(thislist)
print(tropical)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']
# ['mango', 'pineapple', 'papaya', 'apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
del thislist[0:-1]
print(thislist)
# Out:
# ['banana', 'cherry']
# ['cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
#
thislist = ["apple", "banana", "cherry"]
for x in thislist:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
for i in range(len(thislist)):
  print(thislist[i])
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
[print(m) for m in thislist] #shorthand
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = [x for x in fruits if "a" in x] #shorthand
print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
def show_message():
  print("Happy new year")
value = show_message()
print(value)
# Out:
# Happy new year
# None

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
thislist = ["apple","cherry","Banana","date","2fish","1Goat","eagle"]
thislist.sort()
print(thislist)
# Out:
# ['1Goat', '2fish', 'Banana', 'apple', 'cherry', 'date', 'eagle']

# %%
thislist = ["apple","cherry","Banana","date","fish","goat","eagle"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['goat', 'fish', 'eagle', 'date', 'cherry', 'apple', 'Banana']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[2:3]
print(mylist)
# Out:
# ['cherry']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
newlist = thislist[-3:-1]
print(mylist)
print(newlist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana']

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)

list2.extend(list3)
print(list2)
# Out:
# [1, 2, 3]
# [1, 2, 3, 1, 2, 3]

# %%
list1 = ["a", "b", "c", 1, 2, 3, 4]
list2 = [1, 2, 3, 5]

# To 'subtract' elements from list1 that are also in list2
list3 = [item for item in list1 if item in list2]
print(list3)
# Out:
# [1, 2, 3]

# %%
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]
list1.extend(list2)
list3 = list1.copy()
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
mylist = ['apple', 'banana', 'cherry']
i = 0
while i < len(mylist):
  print(mylist[i])
  i = i + 1
# Out:
# apple
# banana
# cherry

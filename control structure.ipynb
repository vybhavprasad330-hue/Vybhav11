# %%
season = input("Enter season (Kharif/Rabi): ").lower()
rainfall = int(input("Enter rainfall in mm: "))
if season == "kharif":
	if rainfall > 600:
		print("Grow Rice")
	else:
		print("Grow Pulses")
else:
	print("Grow Wheat")
# Out:
# Enter season (Kharif/Rabi): rabi
# Enter rainfall in mm: 799
# Grow Wheat

# %%
temperature = 28
humidity = 70
if temperature > 25 and humidity > 60:    	print("High chance of crop disease")
# Out:
# High chance of crop disease

# %%
# Variable Rate Application Example
def calculate_fertilizer(soil_zones):
    """AI determines different fertilizer rates per zone"""
    recommendations = {}
    for zone, nitrogen_level in soil_zones.items():
        if nitrogen_level < 30:
            recommendations[zone] = "High fertilizer (100 kg/ha)"
        elif nitrogen_level < 60:
            recommendations[zone] = "Medium fertilizer (60 kg/ha)"
        else:
            recommendations[zone] = "Low fertilizer (30 kg/ha)"
    return recommendations

zones = {"Zone_A": 25, "Zone_B": 55, "Zone_C": 75}
print(calculate_fertilizer(zones))
# Out:
# {'Zone_A': 'High fertilizer (100 kg/ha)', 'Zone_B': 'Medium fertilizer (60 kg/ha)', 'Zone_C': 'Low fertilizer (30 kg/ha)'}

# %%
for i in range(5,10,3):
	print(i)
# Out:
# 5
# 8

# %%
crops = ["Rice", "Wheat", "Maize"]
for crop in crops:
    print(crop)
# Out:
# Rice
# Wheat
# Maize

# %%
crop = "Rice"
for letter in crop:
    print(letter)
# Out:
# R
# i
# c
# e

# %%
rainfall = [450, 800, 1200, 300]
for r in rainfall:
  if r < 500:
    print(r, "→ Low rainfall")
  elif r < 1000:
    print(r, "→ Moderate rainfall")
  else:
    print(r, "→ Sufficient rainfall")
# Out:
# 450 → Low rainfall
# 800 → Moderate rainfall
# 1200 → Sufficient rainfall
# 300 → Low rainfall

# %%
for i in range(1, 4):
	for j in range(1, 3):
		print(i, j)
# Out:
# 1 1
# 1 2
# 2 1
# 2 2
# 3 1
# 3 2

# %%
for i in range(1, 6):
	if i == 3 or 5:
	   	break
	print(i)

# %%
for i in range(-4, 6):
	if i == 3:
	    continue
	print(i)
# Out:
# -4
# -3
# -2
# -1
# 0
# 1
# 2
# 4
# 5

# %%
for i in range(5):
	print(i)
else:
  print("Loop complete successfully")
# Out:
# 0
# 1
# 2
# 3
# 4
# Loop complete successfully

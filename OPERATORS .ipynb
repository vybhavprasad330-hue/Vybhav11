# %%
#Arithmetic Operators
a = 15
b = 4

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Floor Division:", a // b) 		# Divides and returns the integer part only
print("Modulus:", a % b)
print("Exponentiation:", a ** b)		# Raises the first number to the power of the second (ab)
print("Unary Plus:", +a)
print("Unary Minus:", -a)

# %%
#Arithmetic Operators Use Case:

print("====== FARMER INPUT BASED PROFIT ANALYSIS ======")

seed_cost = float(input("Enter seed cost (INR): "))
fertilizer_cost = float(input("Enter fertilizer cost (INR): "))
pesticide_cost = float(input("Enter pesticide cost (INR): "))
labor_cost = float(input("Enter labor cost (INR): "))
irrigation_cost = float(input("Enter irrigation cost (INR): "))

total_input_cost = seed_cost + fertilizer_cost + pesticide_cost + labor_cost + irrigation_cost
print("\nTotal Input Cost (INR):", total_input_cost)

total_yield_kg = float(input("\nEnter total crop yield (kg): "))
price_per_kg = float(input("Enter selling price per kg (INR): "))

total_revenue = total_yield_kg * price_per_kg
print("Total Revenue (INR):", total_revenue)

profit = total_revenue - total_input_cost
print("Net Profit / Loss (INR):", profit)

profit_per_kg = profit / total_yield_kg
print("Profit per Kg (INR):", profit_per_kg)

total_seed_kg = float(input("\nEnter total seed available (kg): "))
seed_bag_capacity = float(input("Enter seed bag capacity (kg): "))

full_seed_bags = total_seed_kg // seed_bag_capacity
remaining_seed = total_seed_kg % seed_bag_capacity

print("Full Seed Bags Used:", full_seed_bags)
print("Remaining Seed (kg):", remaining_seed)

initial_crop_units = float(input("\nEnter initial crop units: "))
growth_rate = float(input("Enter seasonal growth rate (e.g., 1.10 for 10%): "))
seasons = int(input("Enter number of seasons: "))

expected_crop = initial_crop_units * (growth_rate ** seasons)
print("Expected Crop After Seasons:", expected_crop)

weather_loss = float(input("\nEnter loss due to weather (INR, enter positive value): "))
weather_loss = -weather_loss

adjusted_profit = profit + weather_loss
print("Adjusted Profit After Weather Impact (INR):", adjusted_profit)

positive_view = +adjusted_profit
negative_view = -adjusted_profit

print("Positive Profit View:", positive_view)
print("Negative Profit View:", negative_view)

print("\n====== END OF FARMER ANALYSIS ======")
# Out:
# ====== FARMER INPUT BASED PROFIT ANALYSIS ======
# Enter seed cost (INR): 2500
# Enter fertilizer cost (INR): 2500
# Enter pesticide cost (INR): 1500
# Enter labor cost (INR): 7500
# Enter irrigation cost (INR): 1000
#
# Total Input Cost (INR): 15000.0
#
# Enter total crop yield (kg): 2000
# Enter selling price per kg (INR): 25
# Total Revenue (INR): 50000.0
# Net Profit / Loss (INR): 35000.0
# Profit per Kg (INR): 17.5
#
# Enter total seed available (kg): 1900
# Enter seed bag capacity (kg): 100
# Full Seed Bags Used: 19.0
# Remaining Seed (kg): 0.0
#
# Enter initial crop units: 100
# Enter seasonal growth rate (e.g., 1.10 for 10%): 1.5
# Enter number of seasons: 2
# Expected Crop After Seasons: 225.0
#
# Enter loss due to weather (INR, enter positive value): 10000
# Adjusted Profit After Weather Impact (INR): 25000.0
# Positive Profit View: 25000.0
# Negative Profit View: -25000.0
#
# ====== END OF FARMER ANALYSIS ======

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data for the bar chart
financial_data = {
    'Metric': ['Total Input Cost', 'Total Revenue', 'Net Profit'],
    'Amount (INR)': [total_input_cost, total_revenue, profit]
}
df_financial = pd.DataFrame(financial_data)

# Create the bar chart
plt.figure(figsize=(8, 6))
plt.bar(df_financial['Metric'], df_financial['Amount (INR)'], color=['salmon', 'lightgreen', 'skyblue'])
plt.xlabel('Financial Metric')
plt.ylabel('Amount (INR)')
plt.title('Farmer Financial Analysis: Cost, Revenue, and Profit')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Prepare data for the pie chart
input_cost_data = {
    'Cost Type': ['Seed Cost', 'Fertilizer Cost', 'Pesticide Cost', 'Labor Cost', 'Irrigation Cost'],
    'Amount (INR)': [seed_cost, fertilizer_cost, pesticide_cost, labor_cost, irrigation_cost]
}
df_input_costs = pd.DataFrame(input_cost_data)

# Create the pie chart
plt.figure(figsize=(9, 9))
plt.pie(df_input_costs['Amount (INR)'], labels=df_input_costs['Cost Type'], autopct='%1.1f%%', startangle=90, colors=plt.cm.Paired.colors)
plt.title('Breakdown of Total Input Cost')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %%
#Assignment Operators

a = 34
print("Initial value:", a)

a += 5				#a=a+5
print("After += :", a)		#a=10+5=15

a -= 3				#a=a-3
print("After -= :", a)		#a=15-3=12

a *= 2				#a=a*2
print("After *= :", a)		#a=12*2=24

a /= 4				#a=a/4
print("After /= :", a)		#a=24/4=6

a //= 2				#a=a/2 (floor value)
print("After //= :", a)		#a=6/2=3

a %= 3				#a=a/3 (remainder)
print("After %= :", a)		#a=3/3 (remainder=0)

a **= 2				#a=a2
print("After **= :", a)		#a=02 = 0
# Out:
# Initial value: 34
# After += : 39
# After -= : 36
# After *= : 72
# After /= : 18.0
# After //= : 9.0
# After %= : 0.0
# After **= : 0.0

# %%
#Comparison (Relational) Operators

x = 20**2
y = 15**0

print("x == y :", x == y)
print("x != y :", x != y)
print("x > y  :", x > y)
print("x < y  :", x < y)
print("x >= y :", x >= y)
print("x <= y :", x <= y)
# Out:
# x == y : False
# x != y : True
# x > y  : True
# x < y  : False
# x >= y : True
# x <= y : False

# %%
#Logical Operators
rainfall = True
soil_moisture = False

print("AND:", rainfall and soil_moisture)
print("OR :", rainfall or soil_moisture)
print("NOT:", not rainfall)
# Out:
# AND: False
# OR : True
# NOT: False

# %%
#Logical Operators
rainfall = True
soil_moisture = True
soil_temperature = True
print("AND:", rainfall and  (soil_moisture or not soil_temperature))
print("OR :", rainfall or soil_moisture )
print("NOT:", not rainfall)
# Out:
# AND: True
# OR : True
# NOT: False

# %%
#Identity Operators

a = #Identity Operators

a = [1, 2, 3]
b = a
c = [1, 2, 3]

print("a is b :", a is b)		      #TRUE
print("a equals c :", a == c)     #TRUE
print("a is c :", a is c)		      #FALSE
print("a is c :", a is  c) #TRUE
# Out:
# a is b : True
# a equals c : True
# a is c : False
# a is c : False

# %%
#Membership Operators

crops = ["rice", "wheat", "maize"]

print("rice in crops :", "rice" in crops)
print("ice cream in crops :", "ice cream" in crops)
print("barley not in crops :", "barley" not in crops)
# Out:
# rice in crops : True
# ice cream in crops : False
# barley not in crops : True

# %%
#Bitwise Operators
a = 10
b = 6

print("Bitwise AND (&):", a & b)
print("Bitwise OR (|):", a | b)
print("Bitwise XOR (^):", a ^ b)
print("Bitwise NOT (~a):", ~a)
print("Left Shift (a << 1):", a << 1)
print("Right Shift (a >> 1):", a >> 1)
# Out:
# Bitwise AND (&): 2
# Bitwise OR (|): 14
# Bitwise XOR (^): 12
# Bitwise NOT (~a): -11
# Left Shift (a << 1): 20
# Right Shift (a >> 1): 5

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry", "apple", "cherry")
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'apple', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(len(thistuple))
# Out:
# 3

# %%
thistuple = ("apple",)
print(type(thistuple))

#NOT a tuple
thistuple = ("apple")
print(type(thistuple))
# Out:
# <class 'tuple'>
# <class 'str'>

# %%
thistuple = ["apple",]
print(type(thistuple))

#NOT a tuple
thistuple = ["apple"]
print(type(thistuple))
# Out:
# <class 'list'>
# <class 'list'>

# %%
tuple1 = ("apple", "banana", "cherry")
tuple2 = (1, 5, 7, 9, 3)
tuple3 = (True, False, False)
print(tuple1)
print(tuple2)
print(tuple3)
# Out:
# ('apple', 'banana', 'cherry')
# (1, 5, 7, 9, 3)
# (True, False, False)

# %%
mytuple = ("apple", "banana", "cherry")
print(type(mytuple))
# Out:
# <class 'tuple'>

# %%
tuple1 = ("abc", 34, True, 40, "male")
print(tuple1)
# Out:
# ('abc', 34, True, 40, 'male')

# %%
thistuple = tuple(("apple", "banana", "cherry")) # note the double round-brackets
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[1])
# Out:
# banana

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple[-1])
print(thistuple[2])
# Out:
# cherry
# cherry

# %%
thistuple = ("apple", "banana", "cherry", "orange", "kiwi", "melon", "mango")
print(thistuple[2:5])
print(thistuple[:])
print(thistuple[0:0])
print(thistuple[0:])
print(thistuple[:0])
print(thistuple[2:])
print(thistuple[:5])
print(thistuple[-4:-1])
print(thistuple[:-4])
print(thistuple[-4:])
print(thistuple[2:-4])
print(thistuple[-5:-3])
print(thistuple)
# Out:
# ('cherry', 'orange', 'kiwi')
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')
# ()
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')
# ()
# ('cherry', 'orange', 'kiwi', 'melon', 'mango')
# ('apple', 'banana', 'cherry', 'orange', 'kiwi')
# ('orange', 'kiwi', 'melon')
# ('apple', 'banana', 'cherry')
# ('orange', 'kiwi', 'melon', 'mango')
# ('cherry',)
# ('cherry', 'orange')
# ('apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'mango')

# %%
thistuple = ("apple", "banana", "cherry")
if "apple" in thistuple:
  print("Yes, 'apple' is in the fruits tuple")
  print("apple" in thistuple)
  print("apple" not in thistuple)
else:
  print("No, 'apple' is not in the fruits tuple")
# Out:
# Yes, 'apple' is in the fruits tuple
# True
# False

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
"banana" == "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.append("orange")
thistuple = tuple(y)
print(thistuple)

y.insert(0,"jackfruit")
thistuple = tuple(y)
print(thistuple)

y.remove("banana")
thistuple = tuple(y)
print(thistuple)

y.remove(thistuple[2])
thistuple = tuple(y)
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')
# ('jackfruit', 'apple', 'banana', 'cherry', 'orange')
# ('jackfruit', 'apple', 'cherry', 'orange')
# ('jackfruit', 'apple', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = ("orange",)
thistuple += y
print(thistuple)
thistuple += y
print(thistuple)
# Out:
# ('apple', 'banana', 'cherry', 'orange')
# ('apple', 'banana', 'cherry', 'orange', 'orange')

# %%
thistuple = ("apple", "banana", "cherry")
y = list(thistuple)
y.remove("apple")
thistuple = tuple(y)
print(thistuple)
# Out:
# ('banana', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple  #this will raise an error because the tuple no longer exists

# %%
#packing of tuple
fruits = ("apple", "banana", "cherry")
print(fruits)
# Out:
# ('apple', 'banana', 'cherry')

# %%
#unpacking of tuple
fruits = ("apple", "banana", "cherry")
(green, yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry")

(1, 2, 3) = fruits

print(1)
print(2)
print(3)
# Out:
#   File "/tmp/ipython-input-2059527999.py", line 3
#     (1, 2, 3) = fruits
#      ^
# SyntaxError: cannot assign to literal

# %%
fruits = ("apple", "banana", "cherry")

(A1, A2, A3) = fruits

print(A1)
print(A2)
print(A3)
# Out:
# apple
# banana
# cherry

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, *yellow, red) = fruits

print(green)
print(yellow)
print(red)
# Out:
# apple
# ['banana', 'cherry', 'strawberry']
# raspberry

# %%
fruits = ("apple", "banana", "cherry", "strawberry", "raspberry")

(green, *yellow, red) = fruits

print(green)
print(*yellow)
print(red)
# Out:
# apple
# banana cherry strawberry
# raspberry

# %%
thistuple = ("apple", "banana", "cherry")
for x in thistuple:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
for i in range(len(thistuple)):
  print(thistuple[i])
# Out:
# apple
# banana
# cherry

# %%
thistuple = ("apple", "banana", "cherry")
i = 0
while i < len(thistuple):
  print(thistuple[i])
  i = i + 2
# Out:
# apple
# cherry

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)
tuple1 = tuple1 + tuple2
print(tuple1)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
thistuple = (1,4,6,3,5,2,1,4,9,9,7,8,4,3,5,)
x=thistuple.count("")
y=thistuple.index(4)
z=thistuple.count(9)
c=thistuple.index(5)

b=thistuple.index(9,9)
a=thistuple.index(7)
print(x)
print(y)
print(z)
print(c)
print(d)
print(b)
print(a)
# Out:
# 0
# 1
# 2
# 4
# 4
# 9
# 10

# %%
thistuple = (10, 20, 30, 40, 50, 60, 70, 80)
print(thistuple[:])
print(thistuple[::])
print(thistuple[::-1])
print(thistuple[::-2])
print(thistuple[::2])
print(thistuple[1:5:3])
# Out:
# (10, 20, 30, 40, 50, 60, 70, 80)
# (10, 20, 30, 40, 50, 60, 70, 80)
# (80, 70, 60, 50, 40, 30, 20, 10)
# (80, 60, 40, 20)
# (10, 30, 50, 70)
# (20, 50)

# %%
#NESTED TUPLE
nested = ((1,2,3),(4,5,6), (7,8,9))
print(nested[2])
print(nested[1][1])
print(nested[0][2])
# Out:
# (7, 8, 9)
# 5
# 3

# %%
#built in functions
num = (10,20,30,40)
print(min(num))
print(max(num))
print(sum(num))
# Out:
# 10
# 40
# 100
